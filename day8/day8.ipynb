# %% [markdown]
# Pandas Series & DataFrame

# %%
import pandas as pd
arr=pd.Series([10,20,30,40,50])
print(arr)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# Question 2 — Series Indexing

# %%
import pandas as pd

marks = pd.Series([80, 70, 90, 60, 85])
marks[2]
# Out:
# np.int64(90)

# %% [markdown]
# Question 3 — Series Properties

# %%
marks = pd.Series([80, 70, 90, 60, 85])
marks.shape
marks.size
# Out:
# 5

# %% [markdown]
# Question 4 — DataFrame

# %%
data = {
    "Name": ["Madhu", "Punam", "Rahul"],
    "Marks": [90, 80, 85]
}
df=pd.DataFrame(data)

# %% [markdown]
# Question 5 — Column Access

# %%
df["Marks"]
# Out:
# 0    90
# 1    80
# 2    85
# Name: Marks, dtype: int64

# %% [markdown]
# Question 6 — DataFrame Column

# %%
df = pd.DataFrame({
    "Name": ["Madhu", "Punam", "Rahul"],
    "Marks": [90, 80, 85]
})
df["Name" ]
# Out:
# 0    Madhu
# 1    Punam
# 2    Rahul
# Name: Name, dtype: str

# %% [markdown]
# Question 7 — shape + columns

# %%
df = pd.DataFrame({
    "Name": ["Madhu", "Punam", "Rahul"],
    "Marks": [90, 80, 85]
})

df.shape
df.columns
# Out:
# Index(['Name', 'Marks'], dtype='str')

# %% [markdown]
# Question 8 — iloc

# %%
df = pd.DataFrame({
    "Name": ["Madhu", "Punam", "Rahul"],
    "Marks": [90, 80, 85]
})
df.iloc[0]
# Out:
# Name     Madhu
# Marks       90
# Name: 0, dtype: object

# %% [markdown]
# Question 9 — iloc

# %%
df = pd.DataFrame({
    "Name": ["Madhu", "Punam", "Rahul"],
    "Marks": [90, 80, 85]
})
df.iloc[2]
# Out:
# Name     Rahul
# Marks       85
# Name: 2, dtype: object

# %% [markdown]
# Question 10 — Final Day 8 Challenge

# %%
df = pd.DataFrame({
    "Name": ["Madhu", "Punam", "Rahul", "Amit"],
    "Marks": [90, 80, 85, 70]
})
df[df["Marks"] > 80]
# Out:
#     Name  Marks
# 0  Madhu     90
# 2  Rahul     85

# %% [markdown]
# # Day 08 — Pandas Basics
#
# ## Topics Covered
#
# - Pandas introduction
# - `import pandas as pd`
# - Pandas Series
# - Series indexing
# - Series `shape` and `size`
# - Pandas DataFrame
# - Creating DataFrame from dictionary
# - Accessing DataFrame columns
# - `df.shape`
# - `df.columns`
# - `df.iloc[]` for row selection
# - Boolean filtering
# - Filtering rows based on conditions
#
# ## Practice
#
# - Created a Pandas Series
# - Accessed Series elements using index
# - Checked Series shape and size
# - Created a DataFrame
# - Accessed columns using `df["column"]`
# - Selected rows using `iloc`
# - Filtered DataFrame using conditions
#
# ## Key Learnings
#
# - `pd.Series()` → Creates a one-dimensional labeled data structure
# - `pd.DataFrame()` → Creates a two-dimensional table
# - `df["Marks"]` → Accesses a column
# - `df.shape` → Returns rows and columns
# - `df.columns` → Returns column names
# - `df.iloc[]` → Selects rows using integer positions
# - `df[df["Marks"] > 80]` → Filters rows based on a condition
#
# ## Day 08 Summary
#
# Today I learned the basics of Pandas and practiced working with
# Series and DataFrames, including indexing, column selection,
# row selection, and Boolean filtering.
